# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import rbench as rb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a91f5ff5b769> in <module>
# ----> 1 import rbench as rb
#
# ModuleNotFoundError: No module named 'rbench'

# %%
groebner = rb.read_filetree('../benchmark-results/groebner/2022-05-23', 'groebner').select('boot').deselect(['heapsize', 'valid'])

# %%
groebner.plot.schedule()
# Out:
# <AxesSubplot:xlabel='wall clock time', ylabel='jobs'>

# %%
f5 = rb.read_filetree('../benchmark-results/f5/2022-05-23', 'f5').select('boot').deselect(['heapsize', 'valid'])

# %%
f5.plot.schedule()
# Out:
# <AxesSubplot:xlabel='wall clock time', ylabel='jobs'>

# %%
combo = groebner.join(f5, how='inner')

# %%
combo
# Out:
#                                     groebner                                \
#                                   start_boot cpu_boot gc_boot sigxcpu_boot
# standard/caprasse  2022-05-23 11:34:15+02:00     0.05    0.00          NaN
# standard/cassou    2022-05-23 11:33:48+02:00     0.26    0.01          NaN
# standard/cyclic10  2022-05-23 11:33:51+02:00    30.43    0.00          NaN
# standard/cyclic11  2022-05-23 11:33:48+02:00   173.93    0.02          NaN
# standard/cyclic12  2022-05-23 11:34:16+02:00      NaN     NaN         0.18
# standard/cyclic5   2022-05-23 11:33:48+02:00     0.01    0.01          NaN
# standard/cyclic6   2022-05-23 11:34:15+02:00     0.02    0.01          NaN
# standard/cyclic7   2022-05-23 11:34:04+02:00     0.12    0.01          NaN
# standard/cyclic8   2022-05-23 11:34:14+02:00     0.79    0.00          NaN
# standard/cyclic9   2022-05-23 11:34:05+02:00     5.11    0.01          NaN
# ...

# %%
combo.plot.scatter(x=('groebner', 'cpu_boot'), y=('f5', 'cpu_boot'), color='g')
# Out:
# <AxesSubplot:xlabel='(groebner, cpu_boot)', ylabel='(f5, cpu_boot)'>

# %%
combo.describe()
# Out:
#          groebner                                  f5
#          cpu_boot    gc_boot  sigxcpu_boot   cpu_boot    gc_boot  sigxcpu_boot
# count   24.000000  24.000000  7.000000e+00  25.000000  25.000000  6.000000e+00
# mean    13.962083   0.005833  1.800000e-01   8.011600   0.016800  1.800000e-01
# std     36.536931   0.005836  2.997945e-17  19.981638   0.006272  3.040471e-17
# min      0.000000   0.000000  1.800000e-01   0.000000   0.010000  1.800000e-01
# 25%      0.027500   0.000000  1.800000e-01   0.010000   0.010000  1.800000e-01
# 50%      0.525000   0.010000  1.800000e-01   0.110000   0.020000  1.800000e-01
# 75%      6.360000   0.010000  1.800000e-01   1.500000   0.020000  1.800000e-01
# max    173.930000   0.020000  1.800000e-01  86.220000   0.030000  1.800000e-01
